# %% [markdown]
# <a href="https://colab.research.google.com/github/Javaworld22/FMSDD/blob/master/Michael_Football_predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 0  2023-08-13  14:00  Premier League  Matchweek 1  Sun  Home      D   2   2
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Away      W   3   0
# 2  2023-08-26  15:00  Premier League  Matchweek 3  Sat  Home      D   1   1
# 4  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      D   2   2
# 5  2023-09-16  17:30  Premier League  Matchweek 5  Sat  Away      L   0   1
#
#          opponent  ...  match report  notes  sh  sot  dist   fk pk pkatt  \
# 0       Tottenham  ...  Match Report    NaN  10    5  18.0  0.0  1     1
# 1          Fulham  ...  Match Report    NaN  16    7  13.8  1.0  1     1
# 2  Crystal Palace  ...  Match Report    NaN  12    1  13.7  0.0  0     0
# 4     Bournemouth  ...  Match Report    NaN  21    7  14.7  1.0  0     0
# 5   Newcastle Utd  ...  Match Report    NaN  11    2  15.7  0.0  0     0
#
#    season       team
# 0    2023  Liverpool
# 1    2023  Liverpool
# ...

# %%
matches.shape
# Out:
# (1200, 27)

# %%
# Missing Liverpool 2021-2022
matches["team"].value_counts()
# Out:
# Liverpool                   60
# Arsenal                     60
# Burnley                     60
# Everton                     60
# Luton Town                  60
# Nottingham Forest           60
# Brentford                   60
# Crystal Palace              60
# Bournemouth                 60
# Fulham                      60
# Wolverhampton Wanderers     60
# Chelsea                     60
# Manchester United           60
# Brighton and Hove Albion    60
# Newcastle United            60
# West Ham United             60
# Tottenham Hotspur           60
# Aston Villa                 60
# Manchester City             60
# Sheffield United            60
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Nottingham Forest"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 0   2023-08-13  14:00  Premier League   Matchweek 1  Sun  Home      D   2   2
# 0   2023-08-13  14:00  Premier League   Matchweek 1  Sun  Home      D   2   2
# 0   2023-08-13  14:00  Premier League   Matchweek 1  Sun  Home      D   2   2
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Away      W   3   0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Away      W   3   0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Away      W   3   0
# 2   2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      D   1   1
# 2   2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      D   1   1
# 2   2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      D   1   1
# 4   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      D   2   2
# 4   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      D   2   2
# ...

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     60
# Matchweek 2     60
# Matchweek 20    60
# Matchweek 19    60
# Matchweek 17    60
# Matchweek 16    60
# Matchweek 15    60
# Matchweek 14    60
# Matchweek 13    60
# Matchweek 12    60
# Matchweek 11    60
# Matchweek 10    60
# Matchweek 9     60
# Matchweek 8     60
# Matchweek 7     60
# Matchweek 6     60
# Matchweek 5     60
# Matchweek 4     60
# Matchweek 3     60
# Matchweek 21    60
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh                int64
# sot               int64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]
matches[matches["team"] == "Nottingham Forest"].sort_values("date")
matches.shape
# Out:
# (1200, 26)

# %%
del matches["notes"]
matches[matches["team"] == "Nottingham Forest"].sort_values("date")
matches.shape
# Out:
# (1200, 25)

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# sh                       int64
# sot                      int64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["target"] = (matches["result"] == "W").astype("int")
# matches["target"] = (matches["result"] == "L").astype("float64")
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 0  2023-08-13  14:00   Matchweek 1  Sun  Home      D   2   2        Tottenham
# 1  2023-08-19  15:00   Matchweek 2  Sat  Away      W   3   0           Fulham
# 2  2023-08-26  15:00   Matchweek 3  Sat  Home      D   1   1   Crystal Palace
# 4  2023-09-02  15:00   Matchweek 4  Sat  Home      D   2   2      Bournemouth
# 5  2023-09-16  17:30   Matchweek 5  Sat  Away      L   0   1    Newcastle Utd
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 17 2023-12-09  15:00  Matchweek 16  Sat  Away      L   0   1    Sheffield Utd
# 18 2023-12-17  14:00  Matchweek 17  Sun  Home      L   1   2      Aston Villa
# 19 2023-12-27  19:30  Matchweek 19  Wed  Home      L   1   4           Wolves
# 20 2023-12-30  15:00  Matchweek 20  Sat  Away      L   1   3   Crystal Palace
# 23 2024-01-20  17:30  Matchweek 21  Sat  Home      W   3   2  Nott'ham Forest
#
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 0  2023-08-13  14:00   Matchweek 1  Sun  Home      D   2   2        Tottenham
# 1  2023-08-19  15:00   Matchweek 2  Sat  Away      W   3   0           Fulham
# 2  2023-08-26  15:00   Matchweek 3  Sat  Home      D   1   1   Crystal Palace
# 4  2023-09-02  15:00   Matchweek 4  Sat  Home      D   2   2      Bournemouth
# 5  2023-09-16  17:30   Matchweek 5  Sat  Away      L   0   1    Newcastle Utd
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 17 2023-12-09  15:00  Matchweek 16  Sat  Away      L   0   1    Sheffield Utd
# 18 2023-12-17  14:00  Matchweek 17  Sun  Home      L   1   2      Aston Villa
# 19 2023-12-27  19:30  Matchweek 19  Wed  Home      L   1   4           Wolves
# 20 2023-12-30  15:00  Matchweek 20  Sat  Away      L   1   3   Crystal Palace
# 23 2024-01-20  17:30  Matchweek 21  Sat  Home      W   3   2  Nott'ham Forest
#
# ...

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 0  2023-08-13  14:00   Matchweek 1  Sun  Home      D   2   2        Tottenham
# 1  2023-08-19  15:00   Matchweek 2  Sat  Away      W   3   0           Fulham
# 2  2023-08-26  15:00   Matchweek 3  Sat  Home      D   1   1   Crystal Palace
# 4  2023-09-02  15:00   Matchweek 4  Sat  Home      D   2   2      Bournemouth
# 5  2023-09-16  17:30   Matchweek 5  Sat  Away      L   0   1    Newcastle Utd
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 17 2023-12-09  15:00  Matchweek 16  Sat  Away      L   0   1    Sheffield Utd
# 18 2023-12-17  14:00  Matchweek 17  Sun  Home      L   1   2      Aston Villa
# 19 2023-12-27  19:30  Matchweek 19  Wed  Home      L   1   4           Wolves
# 20 2023-12-30  15:00  Matchweek 20  Sat  Away      L   1   3   Crystal Palace
# 23 2024-01-20  17:30  Matchweek 21  Sat  Home      W   3   2  Nott'ham Forest
#
# ...

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 0  2023-08-13  14:00   Matchweek 1  Sun  Home      D   2   2        Tottenham
# 1  2023-08-19  15:00   Matchweek 2  Sat  Away      W   3   0           Fulham
# 2  2023-08-26  15:00   Matchweek 3  Sat  Home      D   1   1   Crystal Palace
# 4  2023-09-02  15:00   Matchweek 4  Sat  Home      D   2   2      Bournemouth
# 5  2023-09-16  17:30   Matchweek 5  Sat  Away      L   0   1    Newcastle Utd
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 17 2023-12-09  15:00  Matchweek 16  Sat  Away      L   0   1    Sheffield Utd
# 18 2023-12-17  14:00  Matchweek 17  Sun  Home      L   1   2      Aston Villa
# 19 2023-12-27  19:30  Matchweek 19  Wed  Home      L   1   4           Wolves
# 20 2023-12-30  15:00  Matchweek 20  Sat  Away      L   1   3   Crystal Palace
# 23 2024-01-20  17:30  Matchweek 21  Sat  Home      W   3   2  Nott'ham Forest
#
# ...

# %%
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 0  2023-08-13  14:00   Matchweek 1  Sun  Home      D   2   2        Tottenham
# 1  2023-08-19  15:00   Matchweek 2  Sat  Away      W   3   0           Fulham
# 2  2023-08-26  15:00   Matchweek 3  Sat  Home      D   1   1   Crystal Palace
# 4  2023-09-02  15:00   Matchweek 4  Sat  Home      D   2   2      Bournemouth
# 5  2023-09-16  17:30   Matchweek 5  Sat  Away      L   0   1    Newcastle Utd
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 17 2023-12-09  15:00  Matchweek 16  Sat  Away      L   0   1    Sheffield Utd
# 18 2023-12-17  14:00  Matchweek 17  Sun  Home      L   1   2      Aston Villa
# 19 2023-12-27  19:30  Matchweek 19  Wed  Home      L   1   4           Wolves
# 20 2023-12-30  15:00  Matchweek 20  Sat  Away      L   1   3   Crystal Palace
# 23 2024-01-20  17:30  Matchweek 21  Sat  Home      W   3   2  Nott'ham Forest
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-12-25']
train
# Out:
#          date   time         round  day venue result  gf  ga        opponent  \
# 0  2023-08-13  14:00   Matchweek 1  Sun  Home      D   2   2       Tottenham
# 1  2023-08-19  15:00   Matchweek 2  Sat  Away      W   3   0          Fulham
# 2  2023-08-26  15:00   Matchweek 3  Sat  Home      D   1   1  Crystal Palace
# 4  2023-09-02  15:00   Matchweek 4  Sat  Home      D   2   2     Bournemouth
# 5  2023-09-16  17:30   Matchweek 5  Sat  Away      L   0   1   Newcastle Utd
# ..        ...    ...           ...  ...   ...    ...  ..  ..             ...
# 14 2023-11-25  17:30  Matchweek 13  Sat  Home      L   0   1         Arsenal
# 15 2023-12-02  15:00  Matchweek 14  Sat  Home      W   3   1      Luton Town
# 16 2023-12-06  19:30  Matchweek 15  Wed  Away      L   1   2        Brighton
# 17 2023-12-09  15:00  Matchweek 16  Sat  Away      L   0   1   Sheffield Utd
# 18 2023-12-17  14:00  Matchweek 17  Sun  Home      L   1   2     Aston Villa
#
# ...
