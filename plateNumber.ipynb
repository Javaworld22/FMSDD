# %% [markdown]
# <a href="https://colab.research.google.com/github/Javaworld22/FMSDD/blob/master/plateNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/darknet.zip'
# Out:
# Archive:  /content/drive/My Drive/darknet.zip
#    creating: darknet/
#   inflating: darknet/yolov3-tiny_final.weights
#    creating: __MACOSX/
#    creating: __MACOSX/darknet/
#   inflating: __MACOSX/darknet/._yolov3-tiny_final.weights
#   inflating: darknet/LICENSE.mit
#   inflating: darknet/read_plate_number.py
#   inflating: __MACOSX/darknet/._read_plate_number.py
#   inflating: darknet/object_detection_yolo.py
#   inflating: __MACOSX/darknet/._object_detection_yolo.py
#   inflating: darknet/LICENSE
#   inflating: darknet/CRNN_model.py
#   inflating: __MACOSX/darknet/._CRNN_model.py
#    creating: darknet/python/
#   inflating: darknet/python/proverbot.py
#   inflating: darknet/python/darknet.py
#   inflating: darknet/detect_and_remove.py
#   inflating: __MACOSX/darknet/._detect_and_remove.py
#   inflating: darknet/Makefile
#   inflating: __MACOSX/darknet/._Makefile
#   inflating: darknet/LICENSE.meta
#   inflating: darknet/get_images.py
# ...

# %%
# %cd /content/darknet
# !make
# !chmod +x ./darknet
# Out:
# /content/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:957:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/backup /content/darknet

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (520 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# !dos2unix ./data/covid_train.txt
# !dos2unix ./data/covid_test.txt
# !dos2unix ./data/yolo.names
# !dos2unix ./cfg/yolov3-tiny.cfg
# !dos2unix ./data/coco.data
# Out:
# dos2unix: converting file ./data/covid_train.txt to Unix format...
# dos2unix: converting file ./data/covid_test.txt to Unix format...
# dos2unix: converting file ./data/yolo.names to Unix format...
# dos2unix: converting file ./cfg/yolov3-tiny.cfg to Unix format...
# dos2unix: converting file ./data/coco.data to Unix format...

# %%
# %cd /content/darknet
# !./darknet detector train data/coco.data cfg/yolov3-tiny.cfg backup/yolov3-tiny_10000.weights -map
# Out:
# /content/darknet
# yolov3-tiny
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  16  0.319 BFLOPs
#     1 max          2 x 2 / 2   608 x 608 x  16   ->   304 x 304 x  16
#     2 conv     32  3 x 3 / 1   304 x 304 x  16   ->   304 x 304 x  32  0.852 BFLOPs
#     3 max          2 x 2 / 2   304 x 304 x  32   ->   152 x 152 x  32
#     4 conv     64  3 x 3 / 1   152 x 152 x  32   ->   152 x 152 x  64  0.852 BFLOPs
#     5 max          2 x 2 / 2   152 x 152 x  64   ->    76 x  76 x  64
#     6 conv    128  3 x 3 / 1    76 x  76 x  64   ->    76 x  76 x 128  0.852 BFLOPs
#     7 max          2 x 2 / 2    76 x  76 x 128   ->    38 x  38 x 128
#     8 conv    256  3 x 3 / 1    38 x  38 x 128   ->    38 x  38 x 256  0.852 BFLOPs
#     9 max          2 x 2 / 2    38 x  38 x 256   ->    19 x  19 x 256
#    10 conv    512  3 x 3 / 1    19 x  19 x 256   ->    19 x  19 x 512  0.852 BFLOPs
# ...
